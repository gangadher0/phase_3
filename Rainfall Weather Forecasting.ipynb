# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# load dataSet
df=pd.read_csv('weatherAUS.csv')

# %%
df.head(12)
# Out:
#           Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0   2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1   2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2   2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3   2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4   2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# 5   2008-12-06   Albury     14.6     29.7       0.2          NaN       NaN
# 6   2008-12-07   Albury     14.3     25.0       0.0          NaN       NaN
# 7   2008-12-08   Albury      7.7     26.7       0.0          NaN       NaN
# 8   2008-12-09   Albury      9.7     31.9       0.0          NaN       NaN
# 9   2008-12-10   Albury     13.1     30.1       1.4          NaN       NaN
# 10  2008-12-11   Albury     13.4     30.4       0.0          NaN       NaN
# ...

# %%
df.isna().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
df=df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56420 entries, 6049 to 142302
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           56420 non-null  object
#  1   Location       56420 non-null  object
#  2   MinTemp        56420 non-null  float64
#  3   MaxTemp        56420 non-null  float64
#  4   Rainfall       56420 non-null  float64
#  5   Evaporation    56420 non-null  float64
#  6   Sunshine       56420 non-null  float64
#  7   WindGustDir    56420 non-null  object
#  8   WindGustSpeed  56420 non-null  float64
#  9   WindDir9am     56420 non-null  object
#  10  WindDir3pm     56420 non-null  object
#  11  WindSpeed9am   56420 non-null  float64
#  12  WindSpeed3pm   56420 non-null  float64
#  13  Humidity9am    56420 non-null  float64
#  14  Humidity3pm    56420 non-null  float64
#  15  Pressure9am    56420 non-null  float64
#  16  Pressure3pm    56420 non-null  float64
# ...

# %%
df.describe()
# Out:
#             MinTemp       MaxTemp      Rainfall   Evaporation      Sunshine  \
# count  56420.000000  56420.000000  56420.000000  56420.000000  56420.000000
# mean      13.464770     24.219206      2.130397      5.503135      7.735626
# std        6.416689      6.970676      7.014822      3.696282      3.758153
# min       -6.700000      4.100000      0.000000      0.000000      0.000000
# 25%        8.600000     18.700000      0.000000      2.800000      5.000000
# 50%       13.200000     23.900000      0.000000      5.000000      8.600000
# 75%       18.400000     29.700000      0.600000      7.400000     10.700000
# max       31.400000     48.100000    206.200000     81.200000     14.500000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm   Humidity9am   Humidity3pm  \
# count   56420.000000  56420.000000  56420.000000  56420.000000  56420.000000
# mean       40.877366     15.667228     19.786778     65.874123     49.601985
# ...

# %%
df.RainTomorrow.describe()
# Out:
# count     56420
# unique        2
# top          No
# freq      43993
# Name: RainTomorrow, dtype: object

# %%
df.Rainfall.describe()
# Out:
# count    56420.000000
# mean         2.130397
# std          7.014822
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.600000
# max        206.200000
# Name: Rainfall, dtype: float64

# %%
df.tail(5)
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 142298  2017-06-20   Darwin     19.3     33.4       0.0          6.0
# 142299  2017-06-21   Darwin     21.2     32.6       0.0          7.6
# 142300  2017-06-22   Darwin     20.7     32.8       0.0          5.6
# 142301  2017-06-23   Darwin     19.5     31.8       0.0          6.2
# 142302  2017-06-24   Darwin     20.2     31.7       0.0          5.6
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# 142298      11.0         ENE           35.0         SE  ...        63.0
# 142299       8.6           E           37.0         SE  ...        56.0
# 142300      11.0           E           33.0          E  ...        46.0
# 142301      10.6         ESE           26.0         SE  ...        62.0
# 142302      10.7         ENE           30.0        ENE  ...        73.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# ...

# %%
df.Location.describe()
# Out:
# count      56420
# unique        26
# top       Darwin
# freq        3062
# Name: Location, dtype: object

# %%
plt.figure(figsize=(12,5) , dpi=100) # size

plt.scatter(df['Location'] , df['Rainfall'] , color='blue' , marker='o' , s=10)    #coler , marker , s

plt.title('Location & Rainfall' , backgroundcolor='black' , color='white' , fontsize=12) #title
plt.xlabel('Location' , fontsize =10)
plt.ylabel('Rainfall' , fontsize =10)

plt.xticks(rotation=90)   

plt.show()

# %%
#locations label encoder will be used

# %%
from sklearn.preprocessing import LabelEncoder
LabelEncoderModel = LabelEncoder()
df['Location'] = LabelEncoderModel.fit_transform(df['Location'])
df
# Out:
#               Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 6049    2009-01-01         4     17.9     35.2       0.0         12.0
# 6050    2009-01-02         4     18.4     28.9       0.0         14.8
# 6052    2009-01-04         4     19.4     37.6       0.0         10.8
# 6053    2009-01-05         4     21.9     38.4       0.0         11.4
# 6054    2009-01-06         4     24.2     41.0       0.0         11.2
# ...            ...       ...      ...      ...       ...          ...
# 142298  2017-06-20         6     19.3     33.4       0.0          6.0
# 142299  2017-06-21         6     21.2     32.6       0.0          7.6
# 142300  2017-06-22         6     20.7     32.8       0.0          5.6
# 142301  2017-06-23         6     19.5     31.8       0.0          6.2
# 142302  2017-06-24         6     20.2     31.7       0.0          5.6
#
#         Sunshine  WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %%
df['WindGustDir'] = LabelEncoderModel.fit_transform(df['WindGustDir'])
df
# Out:
#               Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 6049    2009-01-01         4     17.9     35.2       0.0         12.0
# 6050    2009-01-02         4     18.4     28.9       0.0         14.8
# 6052    2009-01-04         4     19.4     37.6       0.0         10.8
# 6053    2009-01-05         4     21.9     38.4       0.0         11.4
# 6054    2009-01-06         4     24.2     41.0       0.0         11.2
# ...            ...       ...      ...      ...       ...          ...
# 142298  2017-06-20         6     19.3     33.4       0.0          6.0
# 142299  2017-06-21         6     21.2     32.6       0.0          7.6
# 142300  2017-06-22         6     20.7     32.8       0.0          5.6
# 142301  2017-06-23         6     19.5     31.8       0.0          6.2
# 142302  2017-06-24         6     20.2     31.7       0.0          5.6
#
#         Sunshine  WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %%
df['RainTomorrow'] = LabelEncoderModel.fit_transform(df['RainTomorrow'])  
df['RainToday'] = LabelEncoderModel.fit_transform(df['RainToday'])

# %%
df['WindDir9am'] = LabelEncoderModel.fit_transform(df['WindDir9am'])
df['WindDir3pm'] = LabelEncoderModel.fit_transform(df['WindDir3pm'])
df
# Out:
#               Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 6049    2009-01-01         4     17.9     35.2       0.0         12.0
# 6050    2009-01-02         4     18.4     28.9       0.0         14.8
# 6052    2009-01-04         4     19.4     37.6       0.0         10.8
# 6053    2009-01-05         4     21.9     38.4       0.0         11.4
# 6054    2009-01-06         4     24.2     41.0       0.0         11.2
# ...            ...       ...      ...      ...       ...          ...
# 142298  2017-06-20         6     19.3     33.4       0.0          6.0
# 142299  2017-06-21         6     21.2     32.6       0.0          7.6
# 142300  2017-06-22         6     20.7     32.8       0.0          5.6
# 142301  2017-06-23         6     19.5     31.8       0.0          6.2
# 142302  2017-06-24         6     20.2     31.7       0.0          5.6
#
#         Sunshine  WindGustDir  WindGustSpeed  WindDir9am  ...  Humidity9am  \
# ...

# %%
df['Date']=pd.to_datetime(df['Date'])
df
# Out:
#              Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 6049   2009-01-01         4     17.9     35.2       0.0         12.0
# 6050   2009-01-02         4     18.4     28.9       0.0         14.8
# 6052   2009-01-04         4     19.4     37.6       0.0         10.8
# 6053   2009-01-05         4     21.9     38.4       0.0         11.4
# 6054   2009-01-06         4     24.2     41.0       0.0         11.2
# ...           ...       ...      ...      ...       ...          ...
# 142298 2017-06-20         6     19.3     33.4       0.0          6.0
# 142299 2017-06-21         6     21.2     32.6       0.0          7.6
# 142300 2017-06-22         6     20.7     32.8       0.0          5.6
# 142301 2017-06-23         6     19.5     31.8       0.0          6.2
# 142302 2017-06-24         6     20.2     31.7       0.0          5.6
#
#         Sunshine  WindGustDir  WindGustSpeed  WindDir9am  ...  Humidity9am  \
# ...

# %%
# sort by Date
df.sort_values(by='Date' , inplace=True)
df.tail()
# Out:
#              Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 87199  2017-06-25         1     11.0     24.2       0.0          2.2
# 120637 2017-06-25        16      4.9     16.8       0.0          1.6
# 70392  2017-06-25         8      8.6     14.3       0.0          2.8
# 123830 2017-06-25        15      6.3     17.0       0.0          1.6
# 80997  2017-06-25        23      7.9     13.0       0.0          2.8
#
#         Sunshine  WindGustDir  WindGustSpeed  WindDir9am  ...  Humidity9am  \
# 87199        9.8            1           20.0          11  ...         68.0
# 120637       7.9            0           39.0           0  ...         69.0
# 70392        3.8            7           35.0           3  ...         67.0
# 123830       7.9            0           26.0           9  ...         75.0
# 80997        3.8            6           39.0           3  ...         68.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# ...

# %%
df.describe(include='all').T
# Out:
#                  count                           mean                  min  \
# Date             56420  2012-09-17 06:16:13.952498944  2007-11-01 00:00:00
# Location       56420.0                      12.628837                  0.0
# MinTemp        56420.0                       13.46477                 -6.7
# MaxTemp        56420.0                      24.219206                  4.1
# Rainfall       56420.0                       2.130397                  0.0
# Evaporation    56420.0                       5.503135                  0.0
# Sunshine       56420.0                       7.735626                  0.0
# WindGustDir    56420.0                       7.485537                  0.0
# WindGustSpeed  56420.0                      40.877366                  9.0
# WindDir9am     56420.0                       7.122935                  0.0
# WindDir3pm     56420.0                       7.574424                  0.0
# ...

# %%
# scatter and Rainfall

plt.figure(figsize=(9,5) , dpi=100)
plt.scatter(df['MaxTemp'] , df['Rainfall'] , color='blue' , marker='x' , s=10)    #coler , marker , s
plt.scatter(df['MinTemp'] , df['Rainfall'] , color='red' , marker='o' , s=10)    #coler , marker , s
plt.title('MaxTemp & MinTemp & Rainfall' ,  backgroundcolor='black' , color='white' , fontsize=18)
plt.xlabel('MaxTemp & MinTemp' , fontsize =20)
plt.ylabel('Rainfall' , fontsize =20)


plt.grid()

plt.show()

# %%
plt.figure(figsize=(9,5) , dpi=100)

plt.scatter(df['WindSpeed9am'] , df['Rainfall'] , color='blue' , marker='+' , s=10)    #coler , marker , s
plt.scatter(df['WindSpeed3pm'] , df['Rainfall'] , color='red' , marker='o' , s=10)    #coler , marker , s

plt.title('WindSpeed9am & WindSpeed3pm & Rainfall' ,  backgroundcolor='black' , color='white' , fontsize=12)
plt.xlabel('WindSpeed9am & WindSpeed3pm' , fontsize =14)
plt.ylabel('Rainfall' , fontsize =14)


plt.grid()

plt.show()

# %%
df.Rainfall.describe()
# Out:
# count    56420.000000
# mean         2.130397
# std          7.014822
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.600000
# max        206.200000
# Name: Rainfall, dtype: float64

# %%
df['Year']=df['Date'].dt.year
df['month']=df['Date'].dt.month
df['day']=df['Date'].dt.day
df
# Out:
#              Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 45587  2007-11-01         3      8.0     24.3       0.0          3.4
# 45588  2007-11-02         3     14.0     26.9       3.6          4.4
# 45589  2007-11-03         3     13.7     23.4       3.6          5.8
# 45590  2007-11-04         3     13.3     15.5      39.8          7.2
# 45591  2007-11-05         3      7.6     16.1       2.8          5.6
# ...           ...       ...      ...      ...       ...          ...
# 87199  2017-06-25         1     11.0     24.2       0.0          2.2
# 120637 2017-06-25        16      4.9     16.8       0.0          1.6
# 70392  2017-06-25         8      8.6     14.3       0.0          2.8
# 123830 2017-06-25        15      6.3     17.0       0.0          1.6
# 80997  2017-06-25        23      7.9     13.0       0.0          2.8
#
#         Sunshine  WindGustDir  WindGustSpeed  WindDir9am  ...  Pressure3pm  \
# ...

# %%
new_datamatrix = pd.pivot_table(data=df , values='RainTomorrow' , index='month' , columns='Year')
new_datamatrix
# Out:
# Year       2007      2008      2009      2010      2011      2012      2013  \
# month
# 1           NaN  0.193548  0.147340  0.179259  0.262090  0.232053  0.170248
# 2           NaN  0.296296  0.179724  0.236629  0.256318  0.256318       NaN
# 3           NaN  0.071429  0.174338  0.211111  0.260797  0.230104  0.218333
# 4           NaN  0.148148  0.224784  0.226686       NaN  0.213404  0.189329
# 5           NaN  0.130435  0.176471  0.248555  0.230637  0.228279  0.273187
# 6           NaN  0.115385  0.271341  0.225076  0.234120  0.289703  0.249538
# 7           NaN  0.257485  0.219409  0.223859  0.237435  0.253859  0.251240
# 8           NaN  0.132184  0.246715  0.277860  0.239389  0.214890  0.248739
# 9           NaN  0.159763  0.234074  0.247407  0.196491  0.173045  0.222798
# 10          NaN  0.156627  0.181034  0.286325  0.234528  0.150316  0.180033
# 11     0.266667  0.319527  0.192024  0.264368  0.263245  0.168333  0.239787
# ...

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# Assuming df is your DataFrame
X = df[['Humidity3pm']]
y = df['RainTomorrow']

# Create a linear regression model
model = LinearRegression()
model.fit(X, y)

# Get the coefficients (slope and intercept)
slope = model.coef_[0]
intercept = model.intercept_

plt.xlabel('Humidity at 3pm')
plt.ylabel('Rain Tomorrow')

# Plot the linear regression line
plt.plot(X, model.predict(X), color='red', linewidth=2)
plt.legend(['Linear Regression Line'])
plt.show()

# %%
# Identify the column to move to the last position
column_to_move = 'RainTomorrow'

# Create a copy of the DataFrame with the column removed
df_without_column = df.drop(column_to_move, axis=1)

# Append the column to the end of the DataFrame
df = pd.concat([df, df[column_to_move]], axis=1)

X=df.iloc[:,1:-1]

y=df.iloc[:,-1]
X
# Out:
#         Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 45587          3      8.0     24.3       0.0          3.4       6.3
# 45588          3     14.0     26.9       3.6          4.4       9.7
# 45589          3     13.7     23.4       3.6          5.8       3.3
# 45590          3     13.3     15.5      39.8          7.2       9.1
# 45591          3      7.6     16.1       2.8          5.6      10.6
# ...          ...      ...      ...       ...          ...       ...
# 87199          1     11.0     24.2       0.0          2.2       9.8
# 120637        16      4.9     16.8       0.0          1.6       7.9
# 70392          8      8.6     14.3       0.0          2.8       3.8
# 123830        15      6.3     17.0       0.0          1.6       7.9
# 80997         23      7.9     13.0       0.0          2.8       3.8
#
#         WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  ...  Cloud3pm  \
# 45587             7           30.0          12           7  ...       7.0
# ...

# %%
X=X.drop('RainTomorrow',axis=1)

# %%
X
# Out:
#         Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 45587          3      8.0     24.3       0.0          3.4       6.3
# 45588          3     14.0     26.9       3.6          4.4       9.7
# 45589          3     13.7     23.4       3.6          5.8       3.3
# 45590          3     13.3     15.5      39.8          7.2       9.1
# 45591          3      7.6     16.1       2.8          5.6      10.6
# ...          ...      ...      ...       ...          ...       ...
# 87199          1     11.0     24.2       0.0          2.2       9.8
# 120637        16      4.9     16.8       0.0          1.6       7.9
# 70392          8      8.6     14.3       0.0          2.8       3.8
# 123830        15      6.3     17.0       0.0          1.6       7.9
# 80997         23      7.9     13.0       0.0          2.8       3.8
#
#         WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  ...  Pressure9am  \
# ...

# %%
from sklearn.preprocessing import StandardScaler
StandardScalerModel = StandardScaler()
X = StandardScalerModel.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,shuffle=True,random_state=0,)

# %%
from sklearn.linear_model import LogisticRegression
LogisticRegressionModel = LogisticRegression(penalty='l2', C=1.0, solver='lbfgs', max_iter=10000)
LogisticRegressionModel.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=10000)

# %%
print('Score of train data = ', round(LogisticRegressionModel.score(X_train, y_train), 5))
print('Score of test data = ', round(LogisticRegressionModel.score(X_test, y_test), 5))
# Out:
# Score of train data =  0.85537
# Score of test data =  0.85005

# %%
from sklearn.tree import DecisionTreeClassifier
DecisionTreeClassifierModel = DecisionTreeClassifier()
DecisionTreeClassifierModel.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Model score on the training data
train_score = DecisionTreeClassifierModel.score(X_train, y_train)

# Model score on the testing data
test_score = DecisionTreeClassifierModel.score(X_test, y_test)

print(f"Training Score: {train_score}")
print(f"Testing Score: {test_score}")
# Out:
# Training Score: 1.0
# Testing Score: 0.7976781283232897

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# Make predictions on the testing data
y_pred = DecisionTreeClassifierModel.predict(X_test)

# Evaluate the predictions using different metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1-Score: {f1}")
print(f"Confusion Matrix:\n{conf_matrix}")
# Out:
# Accuracy: 0.7976781283232897
# Precision: 0.5538519072550486
# Recall: 0.5760404511863089
# F1-Score: 0.5647283126787418
# Confusion Matrix:
# [[7520 1193]
#  [1090 1481]]

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
y_pred = DecisionTreeClassifierModel.predict(X_test)
# Assuming you have trained your model and obtained predictions as y_pred

# Compute the confusion matrix
confusion = confusion_matrix(y_test, y_pred)

# Create a heatmap to visualize the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(confusion, annot=True, fmt="d", cmap="Blues",
            xticklabels=["Predicted Negative", "Predicted Positive"],
            yticklabels=["Actual Negative", "Actual Positive"])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(confusion,annot=True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.ensemble import RandomForestClassifier
RandomForestClassifierModel = RandomForestClassifier(n_estimators=10, criterion='entropy')
RandomForestClassifierModel.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10)

# %%
print('Score of train data = ', round(RandomForestClassifierModel.score(X_train, y_train), 4))
print('Score of test data = ', round(RandomForestClassifierModel.score(X_test, y_test), 4))
# Out:
# Score of train data =  0.9887
# Score of test data =  0.847
